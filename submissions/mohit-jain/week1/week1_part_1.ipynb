# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitjainak15-lab/ml_in_astro_csot/blob/main/submissions/mohit-jain/week1/week1_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch as trh
import torchvision as trhvis
import matplotlib.pyplot as plt
print(trh.__version__)
print(trhvis.__version__)
print(trh.cuda.is_available())
print(trh.cuda.get_device_name())
device = "cuda" if trh.cuda.is_available() else "cpu"
print(device)
x=trh.randn(3,64,64)
print(x.shape)
print(x.dtype)
print(x.device)
gpu_tensor=x.to("cuda")
print(gpu_tensor.device)
a=x[0,:,:]
w=a@a
print(w.shape)
# Out:
# 2.10.0+cu128
# 0.25.0+cu128
# True
# Tesla T4
# cuda
# torch.Size([3, 64, 64])
# torch.float32
# cpu
# cuda:0
# torch.Size([64, 64])
